# %%
import pandas as pd

p = pd.read_csv("E:\Project\FootballerPlayerStatistical\data\players_to_value.csv")
print(p.shape)
print("Unique players:", p["merge_key"].nunique())
print(p.head())
# Out:
# (300, 3)
# Unique players: 300
#                Player             Team                          merge_key
# 0      Aaron Ramsdale      Southampton         aaron ramsdale|southampton
# 1   Aaron Wan-Bissaka  West Ham United  aaron wan bissaka|west ham united
# 2  Abdoulaye Doucouré          Everton         abdoulaye doucoure|everton
# 3      Adam Armstrong      Southampton         adam armstrong|southampton
# 4          Adam Smith      Bournemouth             adam smith|bournemouth
